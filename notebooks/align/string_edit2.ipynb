# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../..') # leave the notebooks folder into root as the main

import matplotlib.pyplot as plt
import numpy as np
from dtw import *
import scipy
import librosa

from app.core.audio.AudioData import AudioData
from app.core.audio.AudioPlayer import AudioPlayer
from app.core.midi.MidiData import MidiData
from app.core.midi.MidiPlayer import MidiPlayer
from app.core.midi.MidiSynth import MidiSynth

from app.algorithms.pitch.PYin import PYin
from app.algorithms.align.OnsetDf import UserOnsetDf, MidiOnsetDf
from app.config import AppConfig
from app.core.recording.PitchDf import PitchDf, PitchConfig
from app.algorithms.align.DTW import DTW
from app.algorithms.align.CQT import CQT
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
AUDIO_FILEPATH = '../../app/resources/audio/user_fugue2.mp3'
MIN_VIOLIN_FREQ = 196.0
SAMPLE_RATE = 44100

user_audio_data = AudioData()
user_audio_data.load_data(AUDIO_FILEPATH)
pitches, most_likely_pitches = PYin.pyin(user_audio_data.data)
# Out:
# Processing frame 4604/4604
# Done!

# %%
# Create a synth with a soundfont
SOUNDFONT_FILEPATH = '../../app/resources/MuseScore_General.sf3'
midi_synth = MidiSynth(SOUNDFONT_FILEPATH)

# Load the midi file into a MidiData object
MIDI_FILEPATH = '../../app/resources/midi/fugue.mid'
midi_data = MidiData(MIDI_FILEPATH)

# Create MidiSynth/Player objects
midi_player = MidiPlayer(midi_synth)
midi_player.load_midi(midi_data)

# Also synthesize + convert MIDI to audio (for later CQT extraction)
midi_audio_data = AudioData()
midi_audio_data.load_midi_file(MIDI_FILEPATH, SOUNDFONT_FILEPATH)

# midi_player.play(start_time=0) # Play the MIDI
# Out:
# Loading MidiSynth...
# Synth + soundfont loaded.

# %%
# View the pitch estimates in the app
import sys
sys.path.append('..')

from app.ui.plots.PitchPlot import RunPitchPlot
from app.core.midi.MidiData import MidiData
from PyQt6.QtWidgets import QApplication
from PyQt6.QtCore import QCoreApplication


if __name__ == '__main__':
    if not QCoreApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QCoreApplication.instance()

    # ALIGNED_MIDI_FILEPATH = 'aligned.mid'
    # aligned_midi_data = MidiData(ALIGNED_MIDI_FILEPATH)

    # pitchplot = RunPitchPlot(
    #     app, midi_data=midi_data, pitches=most_likely_pitches, onsets=user_onset2_df.onset_df, align_df=align_df2
    # )
    pitchplot = RunPitchPlot(
        app, midi_data=midi_data, pitches=most_likely_pitches
    )
# Out:
# Plotting pitches...
# Done!
# qt.pointer.dispatch: skipping QEventPoint(id=1 ts=0 pos=0,0 scn=729.825,338.795 gbl=729.825,338.795 Released ellipse=(1x1 ∡ 0) vel=0,0 press=-729.825,-338.795 last=-729.825,-338.795 Δ 729.825,338.795) : no target window
# qt.pointer.dispatch: skipping QEventPoint(id=2 ts=0 pos=0,0 scn=776.267,307.836 gbl=776.267,307.836 Released ellipse=(1x1 ∡ 0) vel=0,0 press=-776.267,-307.836 last=-776.267,-307.836 Δ 776.267,307.836) : no target window

# %%
import pandas as pd

user_onset_df = UserOnsetDf(user_audio_data, most_likely_pitches)

def make_note_df(onset_df, pitch_list):
    """
    Add median pitch MIDI number and duration for each note in onset_df using pitch_list.
    
    Args:
        onset_df (pd.DataFrame): DataFrame with 'time' and 'onset' columns.
        pitch_list (list[Pitch]): List of Pitch objects with 'midi_num' and 'time'.
    
    Returns:
        pd.DataFrame: Updated onset_df with 'median_pitch' and 'duration' columns.
    """
    # Convert pitch_list to a DataFrame for easier manipulation
    pitch_df = pd.DataFrame([(p.time, p.midi_num) for p in pitch_list], columns=['time', 'midi_num'])

    # Initialize result columns
    onset_df['pitch'] = None
    onset_df['duration'] = None

    # Iterate through onset_df to calculate median pitch and duration
    for i in range(len(onset_df) - 1):
        start_time = onset_df.loc[i, 'time']
        end_time = None
        
        if i < len(onset_df) - 1:
            end_time = onset_df.loc[i + 1, 'time']
        else:
            # For the last note, use the maximum time in pitch_df
            end_time = pitch_df['time'].max()

        # Filter pitches within this time range
        note_pitches = pitch_df[(pitch_df['time'] >= start_time) & (pitch_df['time'] <= end_time)]

        # Calculate median pitch and duration
        if not note_pitches.empty:
            median_pitch = note_pitches['midi_num'].median()
            duration = end_time - start_time
        else:
            median_pitch = None
            duration = 0.0

        # Update onset_df for the current row
        onset_df.loc[i, 'pitch'] = median_pitch
        onset_df.loc[i, 'duration'] = duration

    # Handle the last row (no duration since there's no next time)
    onset_df.loc[len(onset_df) - 1, 'pitch'] = None
    onset_df.loc[len(onset_df) - 1, 'duration'] = 0.0

    # Ensure median_pitch and duration are properly cast
    onset_df['pitch'] = onset_df['pitch'].astype(float)
    onset_df['duration'] = onset_df['duration'].astype(float)

    return onset_df

note_df = make_note_df(user_onset_df.onset_df, most_likely_pitches)
note_df
# Out:
# Detecting onsets... Done!
# Detecting pitch changes with rolling median window_size=30 and threshold=0.6... Done!
#          time  pitch_diff  onset      pitch  duration
# 0    0.000000        True   True  62.147640  0.232200
# 1    0.232200       False   True  62.149591  0.063855
# 2    0.296054        True  False  50.111616  0.168345
# 3    0.464399        True   True  61.069563  0.116100
# 4    0.580499        True  False  73.074377  0.081270
# ..        ...         ...    ...        ...       ...
# 77  12.585216       False   True  73.893175  0.119002
# 78  12.704218        True  False  72.270714  0.055147
# 79  12.759365       False   True  72.133982  0.150929
# 80  12.910295       False   True  72.114955  0.107393
# 81  13.017687        True   True        NaN  0.000000
#
# [82 rows x 5 columns]

# %%
midi_data.pitch_df
# Out:
#     note_idx      start  channel  pitch  velocity  duration   frequency
# 0          0   0.000000        0     62       100  0.185938  293.664768
# 1          1   0.187500        0     69       100  0.185938  440.000000
# 2          2   0.375001        0     73       100  0.185938  554.365262
# 3          3   0.562501        0     76       100  0.185938  659.255114
# 4          4   0.750002        0     77       100  0.185938  698.456463
# ..       ...        ...      ...    ...       ...       ...         ...
# 60        60  11.250030        0     63       100  0.185938  311.126984
# 61        61  11.437530        0     74       100  0.185938  587.329536
# 62        62  11.625031        0     79       100  0.185938  783.990872
# 63        63  11.812532        0     72       100  0.185938  523.251131
# 64        64  12.000032        0     78        80  0.373438  739.988845
#
# [65 rows x 7 columns]

# %%
import numpy as np

def row_distance(midi_row, user_row):
    """
    Calculate the custom cost for substituting one note for another.
    
    Parameters:
    midi_row: pandas.Series (row from midi_df)
    user_row: pandas.Series (row from user_df)
    
    Returns:
    float: The cost of substituting midi_row with user_row.
    """
    pitch_cost = abs(midi_row['pitch'] - user_row['pitch']) if not np.isnan(user_row['pitch']) else 10  # Handle NaNs
    duration_cost = abs(midi_row['duration'] - user_row['duration'])
    
    # Weighted sum
    return 0.7 * pitch_cost + 0.3 * duration_cost

def align_notes(midi_df, user_df):
    """
    Align notes from two dataframes using Levenshtein distance with a custom cost function.
    
    Parameters:
    midi_df: pandas.DataFrame (reference MIDI notes)
    user_df: pandas.DataFrame (user-performed notes)
    
    Returns:
    tuple: (distance, alignment) where alignment is a list of tuples showing matched notes.
    """
    m, n = len(midi_df), len(user_df)
    dp = np.zeros((m + 1, n + 1))

    # Initialize the DP table with insertion and deletion costs
    for i in range(1, m + 1):
        dp[i][0] = dp[i - 1][0] + 10  # Deletion cost (midi_df row deleted)
    for j in range(1, n + 1):
        dp[0][j] = dp[0][j - 1] + 10  # Insertion cost (user_df row inserted)

    # Fill the DP table
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            substitution_cost = row_distance(midi_df.iloc[i - 1], user_df.iloc[j - 1])
            dp[i][j] = min(
                dp[i - 1][j] + 10,  # Deletion
                dp[i][j - 1] + 10,  # Insertion
                dp[i - 1][j - 1] + substitution_cost  # Substitution
            )

    # Traceback to find the alignment
    alignment = []
    i, j = m, n
    while i > 0 and j > 0:
        if dp[i][j] == dp[i - 1][j - 1] + row_distance(midi_df.iloc[i - 1], user_df.iloc[j - 1]):
            alignment.append((midi_df.iloc[i - 1], user_df.iloc[j - 1]))  # Match
            i, j = i - 1, j - 1
        elif dp[i][j] == dp[i - 1][j] + 10:
            alignment.append((midi_df.iloc[i - 1], None))  # Deletion
            i -= 1
        else:
            alignment.append((None, user_df.iloc[j - 1]))  # Insertion
            j -= 1

    # Add remaining notes
    while i > 0:
        alignment.append((midi_df.iloc[i - 1], None))  # Deletion
        i -= 1
    while j > 0:
        alignment.append((None, user_df.iloc[j - 1]))  # Insertion
        j -= 1

    return dp[m][n], alignment[::-1]  # Reverse alignment for correct order


distance, alignment = align_notes(midi_data.pitch_df, note_df)

print(f"Total alignment cost: {distance}")
print("Alignment:")
for midi_note, user_note in alignment:
    print(f"MIDI Note: {midi_note}, User Note: {user_note}")
# Out:
# Total alignment cost: 191.17765252331253
# Alignment:
# MIDI Note: note_idx       0.000000
# start          0.000000
# channel        0.000000
# pitch         62.000000
# velocity     100.000000
# duration       0.185938
# frequency    293.664768
# Name: 0, dtype: float64, User Note: time               0.0
# pitch_diff        True
# onset             True
# pitch         62.14764
# duration        0.2322
# Name: 0, dtype: object
# MIDI Note: note_idx       1.000000
# start          0.187500
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 1, dtype: float64, User Note: time             0.2322
# pitch_diff        False
# onset              True
# pitch         62.149591
# duration       0.063855
# Name: 1, dtype: object
# MIDI Note: None, User Note: time           0.296054
# pitch_diff         True
# onset             False
# pitch         50.111616
# duration       0.168345
# Name: 2, dtype: object
# MIDI Note: None, User Note: time           0.464399
# pitch_diff         True
# onset              True
# pitch         61.069563
# duration         0.1161
# Name: 3, dtype: object
# MIDI Note: note_idx       2.000000
# start          0.375001
# channel        0.000000
# pitch         73.000000
# velocity     100.000000
# duration       0.185938
# frequency    554.365262
# Name: 2, dtype: float64, User Note: time           0.580499
# pitch_diff         True
# onset             False
# pitch         73.074377
# duration        0.08127
# Name: 4, dtype: object
# MIDI Note: note_idx       3.000000
# start          0.562501
# channel        0.000000
# pitch         76.000000
# velocity     100.000000
# duration       0.185938
# frequency    659.255114
# Name: 3, dtype: float64, User Note: time           0.661769
# pitch_diff        False
# onset              True
# pitch         73.046043
# duration       0.145125
# Name: 5, dtype: object
# MIDI Note: None, User Note: time           0.806893
# pitch_diff         True
# onset             False
# pitch         64.097539
# duration        0.06966
# Name: 6, dtype: object
# MIDI Note: note_idx       4.000000
# start          0.750002
# channel        0.000000
# pitch         77.000000
# velocity     100.000000
# duration       0.185938
# frequency    698.456463
# Name: 4, dtype: float64, User Note: time           0.876553
# pitch_diff         True
# onset              True
# pitch         76.912532
# duration       0.214785
# Name: 7, dtype: object
# MIDI Note: note_idx       5.000000
# start          0.937503
# channel        0.000000
# pitch         81.000000
# velocity     100.000000
# duration       0.185938
# frequency    880.000000
# Name: 5, dtype: float64, User Note: time           1.091338
# pitch_diff         True
# onset              True
# pitch         81.156343
# duration       0.165442
# Name: 8, dtype: object
# MIDI Note: note_idx       6.000000
# start          1.125003
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 6, dtype: float64, User Note: time            1.25678
# pitch_diff         True
# onset              True
# pitch         74.244037
# duration        0.19737
# Name: 9, dtype: object
# MIDI Note: note_idx       7.000000
# start          1.312504
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 7, dtype: float64, User Note: time            1.45415
# pitch_diff         True
# onset              True
# pitch         72.221066
# duration       0.217687
# Name: 10, dtype: object
# MIDI Note: note_idx       8.000000
# start          1.500004
# channel        0.000000
# pitch         71.000000
# velocity     100.000000
# duration       0.185938
# frequency    493.883301
# Name: 8, dtype: float64, User Note: time           1.671837
# pitch_diff         True
# onset              True
# pitch         71.301811
# duration       0.255419
# Name: 11, dtype: object
# MIDI Note: note_idx       9.000000
# start          1.687505
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 9, dtype: float64, User Note: time           1.927256
# pitch_diff         True
# onset              True
# pitch         74.202934
# duration        0.16254
# Name: 12, dtype: object
# MIDI Note: note_idx      10.000000
# start          1.875005
# channel        0.000000
# pitch         77.000000
# velocity     100.000000
# duration       0.185938
# frequency    698.456463
# Name: 10, dtype: float64, User Note: time          2.089796
# pitch_diff        True
# onset             True
# pitch         76.83193
# duration       0.20898
# Name: 13, dtype: object
# MIDI Note: note_idx      11.000000
# start          2.062506
# channel        0.000000
# pitch         80.000000
# velocity     100.000000
# duration       0.185938
# frequency    830.609395
# Name: 11, dtype: float64, User Note: time           2.298775
# pitch_diff         True
# onset              True
# pitch         80.206846
# duration       0.182857
# Name: 14, dtype: object
# MIDI Note: note_idx      12.000000
# start          2.250006
# channel        0.000000
# pitch         79.000000
# velocity     100.000000
# duration       0.185938
# frequency    783.990872
# Name: 12, dtype: float64, User Note: time           2.481633
# pitch_diff         True
# onset              True
# pitch         79.242804
# duration       0.211882
# Name: 15, dtype: object
# MIDI Note: note_idx      13.000000
# start          2.437506
# channel        0.000000
# pitch         77.000000
# velocity     100.000000
# duration       0.185938
# frequency    698.456463
# Name: 13, dtype: float64, User Note: time           2.693515
# pitch_diff         True
# onset              True
# pitch         77.018913
# duration        0.18576
# Name: 16, dtype: object
# MIDI Note: note_idx      14.000000
# start          2.625007
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 14, dtype: float64, User Note: time           2.879274
# pitch_diff         True
# onset              True
# pitch         75.280403
# duration       0.188662
# Name: 17, dtype: object
# MIDI Note: note_idx      15.000000
# start          2.812507
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 15, dtype: float64, User Note: time           3.067937
# pitch_diff         True
# onset              True
# pitch         74.215654
# duration       0.206077
# Name: 18, dtype: object
# MIDI Note: None, User Note: time           3.274014
# pitch_diff        False
# onset              True
# pitch         74.846647
# duration        0.18576
# Name: 19, dtype: object
# MIDI Note: note_idx      16.000000
# start          3.000008
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 16, dtype: float64, User Note: time           3.459773
# pitch_diff        False
# onset              True
# pitch         75.031711
# duration       0.060952
# Name: 20, dtype: object
# MIDI Note: note_idx      17.000000
# start          3.187508
# channel        0.000000
# pitch         67.000000
# velocity     100.000000
# duration       0.185938
# frequency    391.995436
# Name: 17, dtype: float64, User Note: time           3.520726
# pitch_diff         True
# onset             False
# pitch         67.029222
# duration       0.182857
# Name: 21, dtype: object
# MIDI Note: note_idx      18.000000
# start          3.375009
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 18, dtype: float64, User Note: time           3.703583
# pitch_diff         True
# onset              True
# pitch         71.948452
# duration        0.20898
# Name: 22, dtype: object
# MIDI Note: None, User Note: time           3.912562
# pitch_diff         True
# onset              True
# pitch         72.616371
# duration       0.060952
# Name: 23, dtype: object
# MIDI Note: note_idx      19.000000
# start          3.562509
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 19, dtype: float64, User Note: time           3.973515
# pitch_diff         True
# onset             False
# pitch         73.968724
# duration       0.133515
# Name: 24, dtype: object
# MIDI Note: note_idx      20.000000
# start          3.750010
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 20, dtype: float64, User Note: time           4.107029
# pitch_diff         True
# onset              True
# pitch         75.040156
# duration       0.153832
# Name: 25, dtype: object
# MIDI Note: None, User Note: time           4.260862
# pitch_diff         True
# onset              True
# pitch         74.227068
# duration       0.107392
# Name: 26, dtype: object
# MIDI Note: note_idx      21.000000
# start          3.937510
# channel        0.000000
# pitch         79.000000
# velocity     100.000000
# duration       0.185938
# frequency    783.990872
# Name: 21, dtype: float64, User Note: time           4.368254
# pitch_diff         True
# onset             False
# pitch         79.076191
# duration       0.087075
# Name: 27, dtype: object
# MIDI Note: None, User Note: time           4.455329
# pitch_diff         True
# onset              True
# pitch         72.209424
# duration       0.188662
# Name: 28, dtype: object
# MIDI Note: note_idx      22.000000
# start          4.125011
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 22, dtype: float64, User Note: time           4.643991
# pitch_diff        False
# onset              True
# pitch         71.956856
# duration        0.05805
# Name: 29, dtype: object
# MIDI Note: note_idx      23.000000
# start          4.312511
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 23, dtype: float64, User Note: time           4.702041
# pitch_diff         True
# onset             False
# pitch         70.124167
# duration       0.188662
# Name: 30, dtype: object
# MIDI Note: note_idx      24.000000
# start          4.500012
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 24, dtype: float64, User Note: time          4.890703
# pitch_diff        True
# onset             True
# pitch          69.1699
# duration      0.191565
# Name: 31, dtype: object
# MIDI Note: note_idx      25.000000
# start          4.687512
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 25, dtype: float64, User Note: time           5.082268
# pitch_diff         True
# onset              True
# pitch         72.110735
# duration       0.188662
# Name: 32, dtype: object
# MIDI Note: None, User Note: time            5.27093
# pitch_diff        False
# onset              True
# pitch         44.214335
# duration        0.06966
# Name: 33, dtype: object
# MIDI Note: note_idx      26.000000
# start          4.875013
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 26, dtype: float64, User Note: time            5.34059
# pitch_diff         True
# onset             False
# pitch         74.992677
# duration        0.16254
# Name: 34, dtype: object
# MIDI Note: note_idx      27.000000
# start          5.062513
# channel        0.000000
# pitch         79.000000
# velocity     100.000000
# duration       0.185938
# frequency    783.990872
# Name: 27, dtype: float64, User Note: time           5.503129
# pitch_diff         True
# onset              True
# pitch         79.103701
# duration       0.148027
# Name: 35, dtype: object
# MIDI Note: note_idx      28.000000
# start          5.250014
# channel        0.000000
# pitch         77.000000
# velocity     100.000000
# duration       0.185938
# frequency    698.456463
# Name: 28, dtype: float64, User Note: time           5.651156
# pitch_diff         True
# onset              True
# pitch         76.844693
# duration       0.200272
# Name: 36, dtype: object
# MIDI Note: note_idx      29.000000
# start          5.437514
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 29, dtype: float64, User Note: time           5.851429
# pitch_diff         True
# onset              True
# pitch         75.047078
# duration        0.20898
# Name: 37, dtype: object
# MIDI Note: note_idx      30.000000
# start          5.625015
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 30, dtype: float64, User Note: time           6.060408
# pitch_diff         True
# onset              True
# pitch         74.245247
# duration       0.174149
# Name: 38, dtype: object
# MIDI Note: note_idx      31.000000
# start          5.812515
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 31, dtype: float64, User Note: time           6.234558
# pitch_diff         True
# onset              True
# pitch         72.161525
# duration         0.2322
# Name: 39, dtype: object
# MIDI Note: None, User Note: time           6.466757
# pitch_diff         True
# onset              True
# pitch         73.443648
# duration        0.12771
# Name: 40, dtype: object
# MIDI Note: note_idx      32.000000
# start          6.000016
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 32, dtype: float64, User Note: time           6.594467
# pitch_diff        False
# onset              True
# pitch         73.971186
# duration       0.107392
# Name: 41, dtype: object
# MIDI Note: None, User Note: time           6.701859
# pitch_diff         True
# onset             False
# pitch         50.082163
# duration       0.075465
# Name: 42, dtype: object
# MIDI Note: note_idx      33.000000
# start          6.187516
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 33, dtype: float64, User Note: time           6.777324
# pitch_diff         True
# onset             False
# pitch         69.174908
# duration       0.130612
# Name: 43, dtype: object
# MIDI Note: note_idx      34.000000
# start          6.375017
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 34, dtype: float64, User Note: time           6.907937
# pitch_diff        False
# onset              True
# pitch         70.000687
# duration       0.150929
# Name: 44, dtype: object
# MIDI Note: note_idx      35.000000
# start          6.562517
# channel        0.000000
# pitch         66.000000
# velocity     100.000000
# duration       0.185938
# frequency    369.994423
# Name: 35, dtype: float64, User Note: time          7.058866
# pitch_diff        True
# onset             True
# pitch         65.98335
# duration       0.19737
# Name: 45, dtype: object
# MIDI Note: note_idx      36.000000
# start          6.750018
# channel        0.000000
# pitch         67.000000
# velocity     100.000000
# duration       0.185938
# frequency    391.995436
# Name: 36, dtype: float64, User Note: time           7.256236
# pitch_diff         True
# onset              True
# pitch         66.846383
# duration       0.240907
# Name: 46, dtype: object
# MIDI Note: note_idx      37.000000
# start          6.937518
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 37, dtype: float64, User Note: time           7.497143
# pitch_diff         True
# onset             False
# pitch         69.851686
# duration       0.168345
# Name: 47, dtype: object
# MIDI Note: note_idx      38.000000
# start          7.125019
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 38, dtype: float64, User Note: time           7.665488
# pitch_diff         True
# onset              True
# pitch         73.955196
# duration        0.18576
# Name: 48, dtype: object
# MIDI Note: None, User Note: time           7.851247
# pitch_diff         True
# onset              True
# pitch         46.013531
# duration       0.098685
# Name: 49, dtype: object
# MIDI Note: note_idx      39.000000
# start          7.312519
# channel        0.000000
# pitch         65.000000
# velocity     100.000000
# duration       0.185938
# frequency    349.228231
# Name: 39, dtype: float64, User Note: time           7.949932
# pitch_diff         True
# onset             False
# pitch         64.820422
# duration       0.095782
# Name: 50, dtype: object
# MIDI Note: None, User Note: time           8.045714
# pitch_diff         True
# onset              True
# pitch         64.363414
# duration        0.06966
# Name: 51, dtype: object
# MIDI Note: note_idx      40.000000
# start          7.500020
# channel        0.000000
# pitch         64.000000
# velocity     100.000000
# duration       0.185938
# frequency    329.627557
# Name: 40, dtype: float64, User Note: time           8.115375
# pitch_diff         True
# onset              True
# pitch         64.111617
# duration       0.214784
# Name: 52, dtype: object
# MIDI Note: note_idx      41.000000
# start          7.687520
# channel        0.000000
# pitch         67.000000
# velocity     100.000000
# duration       0.185938
# frequency    391.995436
# Name: 41, dtype: float64, User Note: time           8.330159
# pitch_diff         True
# onset             False
# pitch         67.160676
# duration       0.194467
# Name: 53, dtype: object
# MIDI Note: note_idx      42.000000
# start          7.875021
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 42, dtype: float64, User Note: time           8.524626
# pitch_diff         True
# onset             False
# pitch         70.110995
# duration       0.182857
# Name: 54, dtype: object
# MIDI Note: note_idx      43.000000
# start          8.062521
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 43, dtype: float64, User Note: time           8.707483
# pitch_diff         True
# onset              True
# pitch         74.238086
# duration       0.179955
# Name: 55, dtype: object
# MIDI Note: note_idx      44.000000
# start          8.250022
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 44, dtype: float64, User Note: time           8.887438
# pitch_diff         True
# onset              True
# pitch         72.374707
# duration       0.214785
# Name: 56, dtype: object
# MIDI Note: note_idx      45.000000
# start          8.437522
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 45, dtype: float64, User Note: time           9.102222
# pitch_diff         True
# onset              True
# pitch         69.592067
# duration        0.22059
# Name: 57, dtype: object
# MIDI Note: note_idx      46.000000
# start          8.625023
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 46, dtype: float64, User Note: time           9.322812
# pitch_diff        False
# onset              True
# pitch         69.863895
# duration       0.150929
# Name: 58, dtype: object
# MIDI Note: note_idx      47.000000
# start          8.812523
# channel        0.000000
# pitch         67.000000
# velocity     100.000000
# duration       0.185938
# frequency    391.995436
# Name: 47, dtype: float64, User Note: time           9.473742
# pitch_diff         True
# onset              True
# pitch         66.951056
# duration       0.238005
# Name: 59, dtype: object
# MIDI Note: None, User Note: time           9.711746
# pitch_diff         True
# onset             False
# pitch         66.390858
# duration       0.052245
# Name: 60, dtype: object
# MIDI Note: note_idx      48.000000
# start          9.000024
# channel        0.000000
# pitch         66.000000
# velocity     100.000000
# duration       0.185938
# frequency    369.994423
# Name: 48, dtype: float64, User Note: time           9.763991
# pitch_diff        False
# onset              True
# pitch         65.977014
# duration       0.116099
# Name: 61, dtype: object
# MIDI Note: None, User Note: time          9.880091
# pitch_diff       False
# onset             True
# pitch         66.14247
# duration      0.136417
# Name: 62, dtype: object
# MIDI Note: note_idx      49.000000
# start          9.187524
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 49, dtype: float64, User Note: time          10.016508
# pitch_diff         True
# onset             False
# pitch          69.15278
# duration       0.148027
# Name: 63, dtype: object
# MIDI Note: note_idx      50.000000
# start          9.375025
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 50, dtype: float64, User Note: time          10.164535
# pitch_diff         True
# onset              True
# pitch         72.037933
# duration       0.261224
# Name: 64, dtype: object
# MIDI Note: note_idx      51.000000
# start          9.562525
# channel        0.000000
# pitch         75.000000
# velocity     100.000000
# duration       0.185938
# frequency    622.253967
# Name: 51, dtype: float64, User Note: time           10.42576
# pitch_diff         True
# onset             False
# pitch         75.017777
# duration       0.185759
# Name: 65, dtype: object
# MIDI Note: note_idx      52.000000
# start          9.750026
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 52, dtype: float64, User Note: time          10.611519
# pitch_diff        False
# onset              True
# pitch         74.287566
# duration       0.168345
# Name: 66, dtype: object
# MIDI Note: note_idx      53.000000
# start          9.937526
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 53, dtype: float64, User Note: time          10.779864
# pitch_diff         True
# onset              True
# pitch          72.24667
# duration       0.206077
# Name: 67, dtype: object
# MIDI Note: note_idx      54.000000
# start         10.125027
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 54, dtype: float64, User Note: time          10.985941
# pitch_diff         True
# onset             False
# pitch         69.981812
# duration       0.165442
# Name: 68, dtype: object
# MIDI Note: note_idx      55.000000
# start         10.312527
# channel        0.000000
# pitch         69.000000
# velocity     100.000000
# duration       0.185938
# frequency    440.000000
# Name: 55, dtype: float64, User Note: time          11.151383
# pitch_diff         True
# onset              True
# pitch         69.178898
# duration       0.226395
# Name: 69, dtype: object
# MIDI Note: note_idx      56.000000
# start         10.500028
# channel        0.000000
# pitch         70.000000
# velocity     100.000000
# duration       0.185938
# frequency    466.163762
# Name: 56, dtype: float64, User Note: time          11.377778
# pitch_diff        False
# onset              True
# pitch         69.919894
# duration       0.220589
# Name: 70, dtype: object
# MIDI Note: note_idx      57.000000
# start         10.687528
# channel        0.000000
# pitch         67.000000
# velocity     100.000000
# duration       0.185938
# frequency    391.995436
# Name: 57, dtype: float64, User Note: time          11.598367
# pitch_diff         True
# onset             False
# pitch         67.139354
# duration        0.15093
# Name: 71, dtype: object
# MIDI Note: note_idx      58.000000
# start         10.875029
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 58, dtype: float64, User Note: time          11.749297
# pitch_diff         True
# onset              True
# pitch         74.128953
# duration        0.18576
# Name: 72, dtype: object
# MIDI Note: None, User Note: time          11.935057
# pitch_diff         True
# onset              True
# pitch         46.126947
# duration       0.060952
# Name: 73, dtype: object
# MIDI Note: note_idx      59.000000
# start         11.062529
# channel        0.000000
# pitch         65.000000
# velocity     100.000000
# duration       0.185938
# frequency    349.228231
# Name: 59, dtype: float64, User Note: time          11.996009
# pitch_diff         True
# onset             False
# pitch         64.997019
# duration       0.159637
# Name: 74, dtype: object
# MIDI Note: note_idx      60.000000
# start         11.250030
# channel        0.000000
# pitch         63.000000
# velocity     100.000000
# duration       0.185938
# frequency    311.126984
# Name: 60, dtype: float64, User Note: time          12.155646
# pitch_diff         True
# onset              True
# pitch         63.143271
# duration        0.25542
# Name: 75, dtype: object
# MIDI Note: note_idx      61.000000
# start         11.437530
# channel        0.000000
# pitch         74.000000
# velocity     100.000000
# duration       0.185938
# frequency    587.329536
# Name: 61, dtype: float64, User Note: time          12.411066
# pitch_diff         True
# onset              True
# pitch         74.246629
# duration        0.17415
# Name: 76, dtype: object
# MIDI Note: note_idx      62.000000
# start         11.625031
# channel        0.000000
# pitch         79.000000
# velocity     100.000000
# duration       0.185938
# frequency    783.990872
# Name: 62, dtype: float64, User Note: time          12.585216
# pitch_diff        False
# onset              True
# pitch         73.893175
# duration       0.119002
# Name: 77, dtype: object
# MIDI Note: None, User Note: time          12.704218
# pitch_diff         True
# onset             False
# pitch         72.270714
# duration       0.055147
# Name: 78, dtype: object
# MIDI Note: note_idx      63.000000
# start         11.812532
# channel        0.000000
# pitch         72.000000
# velocity     100.000000
# duration       0.185938
# frequency    523.251131
# Name: 63, dtype: float64, User Note: time          12.759365
# pitch_diff        False
# onset              True
# pitch         72.133982
# duration       0.150929
# Name: 79, dtype: object
# MIDI Note: note_idx      64.000000
# start         12.000032
# channel        0.000000
# pitch         78.000000
# velocity      80.000000
# duration       0.373438
# frequency    739.988845
# Name: 64, dtype: float64, User Note: time          12.910295
# pitch_diff        False
# onset              True
# pitch         72.114955
# duration       0.107393
# Name: 80, dtype: object
# MIDI Note: None, User Note: time          13.017687
# pitch_diff         True
# onset              True
# pitch               NaN
# duration            0.0
# Name: 81, dtype: object

# %%
def classify_notes(alignment, pitch_tolerance=1.0):
    """
    Classify user notes as insertions, deletions, or out-of-tune.

    Parameters:
    alignment: list of tuples (midi_row, user_row)
        Output of the alignment algorithm.
    pitch_tolerance: float
        Tolerance for pitch differences to classify as out-of-tune.

    Returns:
    dict: Dictionary with classifications.
    """
    insertions = []  # User notes with no corresponding MIDI note
    deletions = []   # MIDI notes with no corresponding user note
    out_of_tune = [] # User notes that are out of tune
    matched = []     # Correctly matched notes

    for midi_note, user_note in alignment:
        if midi_note is None:
            # User note is an insertion
            insertions.append(user_note)
        elif user_note is None:
            # MIDI note is a deletion
            deletions.append(midi_note)
        else:
            # Check if the note is out-of-tune
            pitch_diff = abs(midi_note['pitch'] - user_note['pitch'])
            if pitch_diff > pitch_tolerance:
                out_of_tune.append((midi_note, user_note))
            else:
                matched.append((midi_note, user_note))

    return {
        "insertions": insertions,
        "deletions": deletions,
        "out_of_tune": out_of_tune,
        "matched": matched
    }

# Classify notes
classifications = classify_notes(alignment, pitch_tolerance=1.0)

def format_note(note, prefix=""):
    """
    Format a note row as a readable string.
    
    Parameters:
    note: pandas.Series or None
        A row from the DataFrame or None.
    prefix: str
        Prefix to label the type of note.
    
    Returns:
    str: Formatted string representation of the note.
    """
    if note is None:
        return f"{prefix}None"
    # Dynamically check for time or start column
    time_field = 'time' if 'time' in note else 'start'

    return (f"{prefix}Pitch: {note['pitch']:.2f}, "
            f"Duration: {note['duration']:.3f}, "
            f"Time: {note[time_field]:.3f}")


def print_classifications(classifications):
    """
    Print the classifications in a readable format.
    
    Parameters:
    classifications: dict
        Output from the `classify_notes` function.
    """
    print("Insertions (User notes not in MIDI):")
    for note in classifications['insertions']:
        print(format_note(note, prefix="User Note -> "))
    print("\nDeletions (MIDI notes not played by User):")
    for note in classifications['deletions']:
        print(format_note(note, prefix="MIDI Note -> "))
    print("\nOut-of-Tune Notes:")
    for midi_note, user_note in classifications['out_of_tune']:
        print(f"MIDI Note: {format_note(midi_note, prefix='MIDI Note -> ')}")
        print(f"User Note: {format_note(user_note, prefix='User Note -> ')}")
        print()
    print("\nMatched Notes (Correctly aligned):")
    for midi_note, user_note in classifications['matched']:
        print(f"MIDI Note: {format_note(midi_note, prefix='MIDI Note -> ')}")
        print(f"User Note: {format_note(user_note, prefix='User Note -> ')}")
        print()

# Print results in a readable format
print(f"Total Alignment Cost: {distance}\n")
print_classifications(classifications)
# Out:
# Total Alignment Cost: 191.17765252331253
#
# Insertions (User notes not in MIDI):
# User Note -> Pitch: 50.11, Duration: 0.168, Time: 0.296
# User Note -> Pitch: 61.07, Duration: 0.116, Time: 0.464
# User Note -> Pitch: 64.10, Duration: 0.070, Time: 0.807
# User Note -> Pitch: 74.85, Duration: 0.186, Time: 3.274
# User Note -> Pitch: 72.62, Duration: 0.061, Time: 3.913
# User Note -> Pitch: 74.23, Duration: 0.107, Time: 4.261
# User Note -> Pitch: 72.21, Duration: 0.189, Time: 4.455
# User Note -> Pitch: 44.21, Duration: 0.070, Time: 5.271
# User Note -> Pitch: 73.44, Duration: 0.128, Time: 6.467
# User Note -> Pitch: 50.08, Duration: 0.075, Time: 6.702
# User Note -> Pitch: 46.01, Duration: 0.099, Time: 7.851
# User Note -> Pitch: 64.36, Duration: 0.070, Time: 8.046
# User Note -> Pitch: 66.39, Duration: 0.052, Time: 9.712
# User Note -> Pitch: 66.14, Duration: 0.136, Time: 9.880
# User Note -> Pitch: 46.13, Duration: 0.061, Time: 11.935
# User Note -> Pitch: 72.27, Duration: 0.055, Time: 12.704
# User Note -> Pitch: nan, Duration: 0.000, Time: 13.018
#
# Deletions (MIDI notes not played by User):
#
# Out-of-Tune Notes:
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 0.188
# User Note: User Note -> Pitch: 62.15, Duration: 0.064, Time: 0.232
#
# MIDI Note: MIDI Note -> Pitch: 76.00, Duration: 0.186, Time: 0.563
# User Note: User Note -> Pitch: 73.05, Duration: 0.145, Time: 0.662
#
# MIDI Note: MIDI Note -> Pitch: 79.00, Duration: 0.186, Time: 11.625
# User Note: User Note -> Pitch: 73.89, Duration: 0.119, Time: 12.585
#
# MIDI Note: MIDI Note -> Pitch: 78.00, Duration: 0.373, Time: 12.000
# User Note: User Note -> Pitch: 72.11, Duration: 0.107, Time: 12.910
#
#
# Matched Notes (Correctly aligned):
# MIDI Note: MIDI Note -> Pitch: 62.00, Duration: 0.186, Time: 0.000
# User Note: User Note -> Pitch: 62.15, Duration: 0.232, Time: 0.000
#
# MIDI Note: MIDI Note -> Pitch: 73.00, Duration: 0.186, Time: 0.375
# User Note: User Note -> Pitch: 73.07, Duration: 0.081, Time: 0.580
#
# MIDI Note: MIDI Note -> Pitch: 77.00, Duration: 0.186, Time: 0.750
# User Note: User Note -> Pitch: 76.91, Duration: 0.215, Time: 0.877
#
# MIDI Note: MIDI Note -> Pitch: 81.00, Duration: 0.186, Time: 0.938
# User Note: User Note -> Pitch: 81.16, Duration: 0.165, Time: 1.091
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 1.125
# User Note: User Note -> Pitch: 74.24, Duration: 0.197, Time: 1.257
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 1.313
# User Note: User Note -> Pitch: 72.22, Duration: 0.218, Time: 1.454
#
# MIDI Note: MIDI Note -> Pitch: 71.00, Duration: 0.186, Time: 1.500
# User Note: User Note -> Pitch: 71.30, Duration: 0.255, Time: 1.672
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 1.688
# User Note: User Note -> Pitch: 74.20, Duration: 0.163, Time: 1.927
#
# MIDI Note: MIDI Note -> Pitch: 77.00, Duration: 0.186, Time: 1.875
# User Note: User Note -> Pitch: 76.83, Duration: 0.209, Time: 2.090
#
# MIDI Note: MIDI Note -> Pitch: 80.00, Duration: 0.186, Time: 2.063
# User Note: User Note -> Pitch: 80.21, Duration: 0.183, Time: 2.299
#
# MIDI Note: MIDI Note -> Pitch: 79.00, Duration: 0.186, Time: 2.250
# User Note: User Note -> Pitch: 79.24, Duration: 0.212, Time: 2.482
#
# MIDI Note: MIDI Note -> Pitch: 77.00, Duration: 0.186, Time: 2.438
# User Note: User Note -> Pitch: 77.02, Duration: 0.186, Time: 2.694
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 2.625
# User Note: User Note -> Pitch: 75.28, Duration: 0.189, Time: 2.879
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 2.813
# User Note: User Note -> Pitch: 74.22, Duration: 0.206, Time: 3.068
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 3.000
# User Note: User Note -> Pitch: 75.03, Duration: 0.061, Time: 3.460
#
# MIDI Note: MIDI Note -> Pitch: 67.00, Duration: 0.186, Time: 3.188
# User Note: User Note -> Pitch: 67.03, Duration: 0.183, Time: 3.521
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 3.375
# User Note: User Note -> Pitch: 71.95, Duration: 0.209, Time: 3.704
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 3.563
# User Note: User Note -> Pitch: 73.97, Duration: 0.134, Time: 3.974
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 3.750
# User Note: User Note -> Pitch: 75.04, Duration: 0.154, Time: 4.107
#
# MIDI Note: MIDI Note -> Pitch: 79.00, Duration: 0.186, Time: 3.938
# User Note: User Note -> Pitch: 79.08, Duration: 0.087, Time: 4.368
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 4.125
# User Note: User Note -> Pitch: 71.96, Duration: 0.058, Time: 4.644
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 4.313
# User Note: User Note -> Pitch: 70.12, Duration: 0.189, Time: 4.702
#
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 4.500
# User Note: User Note -> Pitch: 69.17, Duration: 0.192, Time: 4.891
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 4.688
# User Note: User Note -> Pitch: 72.11, Duration: 0.189, Time: 5.082
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 4.875
# User Note: User Note -> Pitch: 74.99, Duration: 0.163, Time: 5.341
#
# MIDI Note: MIDI Note -> Pitch: 79.00, Duration: 0.186, Time: 5.063
# User Note: User Note -> Pitch: 79.10, Duration: 0.148, Time: 5.503
#
# MIDI Note: MIDI Note -> Pitch: 77.00, Duration: 0.186, Time: 5.250
# User Note: User Note -> Pitch: 76.84, Duration: 0.200, Time: 5.651
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 5.438
# User Note: User Note -> Pitch: 75.05, Duration: 0.209, Time: 5.851
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 5.625
# User Note: User Note -> Pitch: 74.25, Duration: 0.174, Time: 6.060
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 5.813
# User Note: User Note -> Pitch: 72.16, Duration: 0.232, Time: 6.235
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 6.000
# User Note: User Note -> Pitch: 73.97, Duration: 0.107, Time: 6.594
#
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 6.188
# User Note: User Note -> Pitch: 69.17, Duration: 0.131, Time: 6.777
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 6.375
# User Note: User Note -> Pitch: 70.00, Duration: 0.151, Time: 6.908
#
# MIDI Note: MIDI Note -> Pitch: 66.00, Duration: 0.186, Time: 6.563
# User Note: User Note -> Pitch: 65.98, Duration: 0.197, Time: 7.059
#
# MIDI Note: MIDI Note -> Pitch: 67.00, Duration: 0.186, Time: 6.750
# User Note: User Note -> Pitch: 66.85, Duration: 0.241, Time: 7.256
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 6.938
# User Note: User Note -> Pitch: 69.85, Duration: 0.168, Time: 7.497
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 7.125
# User Note: User Note -> Pitch: 73.96, Duration: 0.186, Time: 7.665
#
# MIDI Note: MIDI Note -> Pitch: 65.00, Duration: 0.186, Time: 7.313
# User Note: User Note -> Pitch: 64.82, Duration: 0.096, Time: 7.950
#
# MIDI Note: MIDI Note -> Pitch: 64.00, Duration: 0.186, Time: 7.500
# User Note: User Note -> Pitch: 64.11, Duration: 0.215, Time: 8.115
#
# MIDI Note: MIDI Note -> Pitch: 67.00, Duration: 0.186, Time: 7.688
# User Note: User Note -> Pitch: 67.16, Duration: 0.194, Time: 8.330
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 7.875
# User Note: User Note -> Pitch: 70.11, Duration: 0.183, Time: 8.525
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 8.063
# User Note: User Note -> Pitch: 74.24, Duration: 0.180, Time: 8.707
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 8.250
# User Note: User Note -> Pitch: 72.37, Duration: 0.215, Time: 8.887
#
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 8.438
# User Note: User Note -> Pitch: 69.59, Duration: 0.221, Time: 9.102
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 8.625
# User Note: User Note -> Pitch: 69.86, Duration: 0.151, Time: 9.323
#
# MIDI Note: MIDI Note -> Pitch: 67.00, Duration: 0.186, Time: 8.813
# User Note: User Note -> Pitch: 66.95, Duration: 0.238, Time: 9.474
#
# MIDI Note: MIDI Note -> Pitch: 66.00, Duration: 0.186, Time: 9.000
# User Note: User Note -> Pitch: 65.98, Duration: 0.116, Time: 9.764
#
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 9.188
# User Note: User Note -> Pitch: 69.15, Duration: 0.148, Time: 10.017
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 9.375
# User Note: User Note -> Pitch: 72.04, Duration: 0.261, Time: 10.165
#
# MIDI Note: MIDI Note -> Pitch: 75.00, Duration: 0.186, Time: 9.563
# User Note: User Note -> Pitch: 75.02, Duration: 0.186, Time: 10.426
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 9.750
# User Note: User Note -> Pitch: 74.29, Duration: 0.168, Time: 10.612
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 9.938
# User Note: User Note -> Pitch: 72.25, Duration: 0.206, Time: 10.780
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 10.125
# User Note: User Note -> Pitch: 69.98, Duration: 0.165, Time: 10.986
#
# MIDI Note: MIDI Note -> Pitch: 69.00, Duration: 0.186, Time: 10.313
# User Note: User Note -> Pitch: 69.18, Duration: 0.226, Time: 11.151
#
# MIDI Note: MIDI Note -> Pitch: 70.00, Duration: 0.186, Time: 10.500
# User Note: User Note -> Pitch: 69.92, Duration: 0.221, Time: 11.378
#
# MIDI Note: MIDI Note -> Pitch: 67.00, Duration: 0.186, Time: 10.688
# User Note: User Note -> Pitch: 67.14, Duration: 0.151, Time: 11.598
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 10.875
# User Note: User Note -> Pitch: 74.13, Duration: 0.186, Time: 11.749
#
# MIDI Note: MIDI Note -> Pitch: 65.00, Duration: 0.186, Time: 11.063
# User Note: User Note -> Pitch: 65.00, Duration: 0.160, Time: 11.996
#
# MIDI Note: MIDI Note -> Pitch: 63.00, Duration: 0.186, Time: 11.250
# User Note: User Note -> Pitch: 63.14, Duration: 0.255, Time: 12.156
#
# MIDI Note: MIDI Note -> Pitch: 74.00, Duration: 0.186, Time: 11.438
# User Note: User Note -> Pitch: 74.25, Duration: 0.174, Time: 12.411
#
# MIDI Note: MIDI Note -> Pitch: 72.00, Duration: 0.186, Time: 11.813
# User Note: User Note -> Pitch: 72.13, Duration: 0.151, Time: 12.759
